# %%
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding
import matplotlib.pyplot as plt

# %%
X_swiss, t = make_swiss_roll(n_samples=1000, noise=0.2, random_state=42)

# %%
X_swiss[0]
# Out:
# array([-3.29677117,  4.26198454,  7.69787682])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax = plt.axes(projection='3d')

ax.scatter(X_swiss[: , 0], X_swiss[: , 1], X_swiss[: , 2], c=t, )
ax.view_init(azim=-50, elev=10)

# %%
lle = LocallyLinearEmbedding(n_neighbors=10)
X_reducted = lle.fit_transform(X_swiss)

# %%
plt.scatter(X_reducted[:, 0], X_reducted[: , 1], c=t)

# %%
import numpy as np

# %%
np.random.randn(7300, 20000) / np.sqrt(7300)
# Out:
# array([[ 0.00273883,  0.01131096, -0.0070219 , ..., -0.00076754,
#         -0.0115991 , -0.00483389],
#        [ 0.01263595,  0.0073393 ,  0.00012306, ...,  0.0032715 ,
#         -0.00331541,  0.00192635],
#        [-0.00195065,  0.00243914, -0.014456  , ..., -0.00207505,
#          0.00501821,  0.0031786 ],
#        ...,
#        [ 0.00198532, -0.01360266,  0.01032695, ..., -0.00620315,
#          0.0059468 , -0.0081677 ],
#        [ 0.00422033, -0.00024556, -0.00194234, ..., -0.00124361,
#         -0.00467758, -0.004258  ],
#        [-0.00078628,  0.00913649, -0.01121506, ...,  0.00106847,
#         -0.00889776,  0.00293316]])
