# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=6)
plt.scatter(X[: , 0], X[:, 1], c=y)

# %%
intertia = []
clusters_ = range(1, 10)

for item in clusters_:
    km = KMeans(n_clusters=item)
    km.fit(X)
    intertia.append(km.inertia_)

plt.plot(clusters_, intertia)

# %%
km = KMeans(n_clusters=4)
y_cluster = km.fit_predict(X)
plt.scatter(X[: , 0], X[:, 1], c=y_cluster)
